# %%
import astropy.units as u
from sbpy.photometry import HG, HG1G2, HG12, HG12_Pen16
m = HG()
print(m)
# Out:
# WARNING: AstropyDeprecationWarning: The TestRunner class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.tests.runner]
# WARNING: AstropyDeprecationWarning: The TestRunnerBase class is deprecated and may be removed in a future version.
#         Use pytest instead. [astropy.utils.decorators]
# Model: HG
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Parameters:
#      H   G
#     --- ---
#     8.0 0.4

# %%
m = HG(H = 25 * u.mag, G = 0.15, radius = 15 * u.km, wfb = 'V')
print(m)
# Out:
# Model: HG
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Parameters:
#      H    G
#     mag
#     ---- ----
#     25.0 0.15

# %%
import astropy.units as u
from sbpy.calib import solar_fluxd

print(m.geomalb)  

print(m.bondalb)  

print(m.phaseint)
# Out:
# /home/garcia/venv/neo_detect/lib64/python3.11/site-packages/sbpy/utils/core.py:97: OptionalPackageUnavailable: `synphot`.
#   warn(
# /home/garcia/venv/neo_detect/lib64/python3.11/site-packages/sbpy/utils/core.py:97: OptionalPackageUnavailable: `synphot`.
#   warn(
# /home/garcia/venv/neo_detect/lib64/python3.11/site-packages/sbpy/utils/core.py:97: OptionalPackageUnavailable: `synphot`.
#   warn(
# /home/garcia/venv/neo_detect/lib64/python3.11/site-packages/sbpy/utils/core.py:97: OptionalPackageUnavailable: `synphot`.
#   warn(
# 1.9483559672657158e-07
# 7.48245080589615e-08
# 0.3840392069831507
